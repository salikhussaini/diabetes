# %%
#Import mathplotLib
import matplotlib.pyplot as plt
#Pandas
import pandas as pd
#Numpy
import numpy as np

#Import Train_test_split
from sklearn.model_selection import GridSearchCV, train_test_split

#Load Data
data = pd.read_csv('diabetic_data_1.csv')
data.head()
# Out:
#    Caucasian  AfricanAmerican  Asian  Hispanic  Other  Unknown  Female  Male  \
# 0          1                0      0         0      0        0       1     0
# 1          0                1      0         0      0        0       1     0
# 2          1                0      0         0      0        0       0     1
# 3          1                0      0         0      0        0       0     1
# 4          1                0      0         0      0        0       0     1
#
#    Age_0-10  Age_10-20       ...        glipizide-metformin  \
# 0         0          1       ...                         No
# 1         0          0       ...                         No
# 2         0          0       ...                         No
# 3         0          0       ...                         No
# 4         0          0       ...                         No
#
#    glimepiride-pioglitazone  metformin-rosiglitazone  metformin-pioglitazone  \
# ...

# %%
x = data
y1 = data['readmitted_No']
y2 = data['readmitted_<30']
y3 = data['readmitted_>30']
y4 = data['readmitted']
y1 = pd.DataFrame(y1)
y2 = pd.DataFrame(y2)
y3 = pd.DataFrame(y3)
y4 = pd.DataFrame(y4)

# %%
from sklearn.preprocessing import StandardScaler

x = data.drop(['readmitted_No' , 'readmitted_<30', 'readmitted_>30','readmitted'], axis = 1)
x = data[["Caucasian","AfricanAmerican","Asian","Hispanic","Other",
          "Unknown","Female","Male","Age_0-10","Age_10-20","Age_20-30","Age_30-40","Age_40-50","Age_50-60","Age_60-70","Age_70-80","Age_80-90","Age_98","admission_type_id","discharge_disposition_id","admission_source_id","time_in_hospital","num_lab_procedures","num_procedures","num_medications","number_outpatient","number_emergency","number_inpatient","number_diagnoses"]]
autoscaler = StandardScaler()
x = autoscaler.fit_transform(x)
x = pd.DataFrame(x)
x.head()
# Out:
#          0         1         2         3        4         5         6   \
# 0  0.580762 -0.482380 -0.079616 -0.142917 -0.12256 -0.151148  0.927452
# 1 -1.721876  2.073054 -0.079616 -0.142917 -0.12256 -0.151148  0.927452
# 2  0.580762 -0.482380 -0.079616 -0.142917 -0.12256 -0.151148 -1.078223
# 3  0.580762 -0.482380 -0.079616 -0.142917 -0.12256 -0.151148 -1.078223
# 4  0.580762 -0.482380 -0.079616 -0.142917 -0.12256 -0.151148 -1.078223
#
#          7         8          9     ...           19        20        21  \
# 0 -0.927397 -0.039807  12.094359    ...    -0.514312  0.306482 -0.467653
# 1 -0.927397 -0.039807  -0.082683    ...    -0.514312  0.306482 -0.802651
# 2  1.078287 -0.039807  -0.082683    ...    -0.514312  0.306482 -0.802651
# 3  1.078287 -0.039807  -0.082683    ...    -0.514312  0.306482 -1.137649
# 4  1.078287 -0.039807  -0.082683    ...    -0.514312 -0.923814 -0.467653
#
#          22        23        24        25       26        27        28
# ...

# %%
#Split dataset into 80% train, 20% test
X_train, X_test, y_train, y_test = train_test_split(x, y1, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
# Out:
# C:\Users\salik\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.40      0.49      9293
#            1       0.62      0.81      0.70     11061
#
#     accuracy                           0.62     20354
#    macro avg       0.63      0.60      0.60     20354
# weighted avg       0.63      0.62      0.60     20354
